# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Leer Datos csv

# %%
df_1 = pd.read_csv(r'../datos/titanic.csv', sep=';')
df_1.head()
# Out:
#    Unnamed: 0  clase  supervivencia  \
# 0           0      1              1
# 1           1      1              1
# 2           2      1              0
# 3           3      1              0
# 4           4      1              0
#
#                                             nombre    sexo    edad  ticket  \
# 0                    Allen, Miss. Elisabeth Walton  female      29   24160
# 1                   Allison, Master. Hudson Trevor    male  0,9167  113781
# 2                     Allison, Miss. Helen Loraine  female       2  113781
# 3             Allison, Mr. Hudson Joshua Creighton    male      30  113781
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female      25  113781
#
#     cabina embarque                  partida/destino
# 0       B5        S                     St Louis, MO
# 1  C22 C26        S  Montreal, PQ / Chesterville, ON
# 2  C22 C26        S  Montreal, PQ / Chesterville, ON
# 3  C22 C26        S  Montreal, PQ / Chesterville, ON
# ...

# %%
col_n = df_1.columns.values[1:]
col_n
# Out:
# array(['clase', 'supervivencia', 'nombre', 'sexo', 'edad', 'ticket',
#        'cabina', 'embarque', 'partida/destino'], dtype=object)

# %%
df_2 = df_1[col_n]
df_2.head()
# Out:
#    clase  supervivencia                                           nombre  \
# 0      1              1                    Allen, Miss. Elisabeth Walton
# 1      1              1                   Allison, Master. Hudson Trevor
# 2      1              0                     Allison, Miss. Helen Loraine
# 3      1              0             Allison, Mr. Hudson Joshua Creighton
# 4      1              0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#      sexo    edad  ticket   cabina embarque                  partida/destino
# 0  female      29   24160       B5        S                     St Louis, MO
# 1    male  0,9167  113781  C22 C26        S  Montreal, PQ / Chesterville, ON
# 2  female       2  113781  C22 C26        S  Montreal, PQ / Chesterville, ON
# 3    male      30  113781  C22 C26        S  Montreal, PQ / Chesterville, ON
# 4  female      25  113781  C22 C26        S  Montreal, PQ / Chesterville, ON

# %% [markdown]
# ### Verificar valores vacíos

# %%
df_2.isna()
# Out:
#       clase  supervivencia  nombre   sexo   edad  ticket  cabina  embarque  \
# 0     False          False   False  False  False   False   False     False
# 1     False          False   False  False  False   False   False     False
# 2     False          False   False  False  False   False   False     False
# 3     False          False   False  False  False   False   False     False
# 4     False          False   False  False  False   False   False     False
# ...     ...            ...     ...    ...    ...     ...     ...       ...
# 1304  False          False   False  False  False   False    True     False
# 1305  False          False   False  False   True   False    True     False
# 1306  False          False   False  False  False   False    True     False
# 1307  False          False   False  False  False   False    True     False
# 1308  False          False   False  False  False   False    True     False
#
#       partida/destino
# 0               False
# ...

# %% [markdown]
# ### Verificar valores no vacíos

# %%
df_2.notna()
# Out:
#       clase  supervivencia  nombre  sexo   edad  ticket  cabina  embarque  \
# 0      True           True    True  True   True    True    True      True
# 1      True           True    True  True   True    True    True      True
# 2      True           True    True  True   True    True    True      True
# 3      True           True    True  True   True    True    True      True
# 4      True           True    True  True   True    True    True      True
# ...     ...            ...     ...   ...    ...     ...     ...       ...
# 1304   True           True    True  True   True    True   False      True
# 1305   True           True    True  True  False    True   False      True
# 1306   True           True    True  True   True    True   False      True
# 1307   True           True    True  True   True    True   False      True
# 1308   True           True    True  True   True    True   False      True
#
#       partida/destino
# 0                True
# 1                True
# ...

# %% [markdown]
# ### Dimensiones del DataFrame

# %%
df_2.shape
# Out:
# (1309, 9)

# %% [markdown]
# ### Sumar valores no vacíos

# %%
df_2[col_n[1]].notna().sum()
# Out:
# 1309

# %%
df_2[col_n[4]].notna().sum()
# Out:
# 1046

# %% [markdown]
# ### Eliminar todas las filas con valores vacíos

# %%
df_2.dropna()
# Out:
#      clase  supervivencia                                           nombre  \
# 0        1              1                    Allen, Miss. Elisabeth Walton
# 1        1              1                   Allison, Master. Hudson Trevor
# 2        1              0                     Allison, Miss. Helen Loraine
# 3        1              0             Allison, Mr. Hudson Joshua Creighton
# 4        1              0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ..     ...            ...                                              ...
# 520      2              1     Nourney, Mr. Alfred ("Baron von Drachstedt")
# 521      2              1                     Nye, Mrs. (Elizabeth Ramell)
# 573      2              1              Troutt, Miss. Edwina Celia "Winnie"
# 584      2              1                              Webber, Miss. Susan
# 605      3              1                    Abelseth, Mr. Olaus Jorgensen
#
#        sexo    edad         ticket   cabina embarque  \
# ...

# %% [markdown]
# ### Rellenar todos los valores vacíos

# %%
df_2.fillna(0)
# Out:
#       clase  supervivencia                                           nombre  \
# 0         1              1                    Allen, Miss. Elisabeth Walton
# 1         1              1                   Allison, Master. Hudson Trevor
# 2         1              0                     Allison, Miss. Helen Loraine
# 3         1              0             Allison, Mr. Hudson Joshua Creighton
# 4         1              0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...     ...            ...                                              ...
# 1304      3              0                             Zabour, Miss. Hileni
# 1305      3              0                            Zabour, Miss. Thamine
# 1306      3              0                        Zakarian, Mr. Mapriededer
# 1307      3              0                              Zakarian, Mr. Ortin
# 1308      3              0                               Zimmerman, Mr. Leo
#
#         sexo    edad  ticket   cabina embarque  \
# ...

# %%
df_2.fillna('Sin dato')
# Out:
#       clase  supervivencia                                           nombre  \
# 0         1              1                    Allen, Miss. Elisabeth Walton
# 1         1              1                   Allison, Master. Hudson Trevor
# 2         1              0                     Allison, Miss. Helen Loraine
# 3         1              0             Allison, Mr. Hudson Joshua Creighton
# 4         1              0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...     ...            ...                                              ...
# 1304      3              0                             Zabour, Miss. Hileni
# 1305      3              0                            Zabour, Miss. Thamine
# 1306      3              0                        Zakarian, Mr. Mapriededer
# 1307      3              0                              Zakarian, Mr. Ortin
# 1308      3              0                               Zimmerman, Mr. Leo
#
#         sexo      edad  ticket    cabina embarque  \
# ...

# %% [markdown]
# ### Variables dummy

# %%
var_dummy = pd.get_dummies(df_2["sexo"], prefix="sexo")
var_dummy
# Out:
#       sexo_female  sexo_male
# 0               1          0
# 1               0          1
# 2               1          0
# 3               0          1
# 4               1          0
# ...           ...        ...
# 1304            1          0
# 1305            1          0
# 1306            0          1
# 1307            0          1
# 1308            0          1
#
# [1309 rows x 2 columns]

# %%
var_dummy.sum()
# Out:
# sexo_female    466
# sexo_male      843
# dtype: int64

# %%
var_dummy.mean()
# Out:
# sexo_female    0.355997
# sexo_male      0.644003
# dtype: float64

# %% [markdown]
# ### Leer Datos excel

# %%
df_3 = pd.read_excel(r'../datos/titanic.xls')
df_3.head()
# Out:
#    Unnamed: 0  clase  supervivencia  \
# 0           0      1              1
# 1           1      1              1
# 2           2      1              0
# 3           3      1              0
# 4           4      1              0
#
#                                             nombre    sexo     edad  ticket  \
# 0                    Allen, Miss. Elisabeth Walton  female  29.0000   24160
# 1                   Allison, Master. Hudson Trevor    male   0.9167  113781
# 2                     Allison, Miss. Helen Loraine  female   2.0000  113781
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.0000  113781
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000  113781
#
#     cabina embarque                  partida/destino
# 0       B5        S                     St Louis, MO
# 1  C22 C26        S  Montreal, PQ / Chesterville, ON
# 2  C22 C26        S  Montreal, PQ / Chesterville, ON
# 3  C22 C26        S  Montreal, PQ / Chesterville, ON
# ...

# %% [markdown]
# ### Leer Datos JSON

# %%
df_4 = pd.read_json(r'../datos/titanic.json')
df_4.head()
# Out:
#    Unnamed: 0  clase  supervivencia  \
# 0           0      1              1
# 1           1      1              1
# 2           2      1              0
# 3           3      1              0
# 4           4      1              0
#
#                                             nombre    sexo    edad  ticket  \
# 0                    Allen, Miss. Elisabeth Walton  female      29   24160
# 1                   Allison, Master. Hudson Trevor    male  0,9167  113781
# 2                     Allison, Miss. Helen Loraine  female       2  113781
# 3             Allison, Mr. Hudson Joshua Creighton    male      30  113781
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female      25  113781
#
#     cabina embarque                  partida/destino
# 0       B5        S                     St Louis, MO
# 1  C22 C26        S  Montreal, PQ / Chesterville, ON
# 2  C22 C26        S  Montreal, PQ / Chesterville, ON
# 3  C22 C26        S  Montreal, PQ / Chesterville, ON
# ...

# %% [markdown]
# ### Exportar a un archivo excel

# %%
df_2.fillna('Sin dato').to_excel('../resultados/titanic_custom.xls') # excel 2003
df_2.fillna('Sin dato').to_excel('../resultados/titanic_custom.xlsx') # excel 2016

# %% [markdown]
# ### Exportar a un archivo csv

# %%
df_2.fillna('Sin dato').to_csv('../resultados/titanic_custom.csv')

# %% [markdown]
# ### Exportar a un archivo JSON

# %%
df_2.fillna('Sin dato').to_json('../resultados/titanic_custom.json')
